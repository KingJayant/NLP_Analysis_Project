# %% [markdown]
# # Text Generation

# %% [markdown]
# ## Introduction

# %% [markdown]
# Markov chains can be used for very basic text generation. Think about every word in a corpus as a state. We can make a simple assumption that the next word is only dependent on the previous word - which is the basic assumption of a Markov chain.
#
# Markov chains don't generate text as well as deep learning, but it's a good (and fun!) start.

# %% [markdown]
# ## Select Text to Imitate

# %% [markdown]
# In this notebook, we're specifically going to generate text in the style of Ali Wong, so as a first step, let's extract the text from her comedy routine.

# %%
# Read in the corpus, including punctuation!
import pandas as pd

data = pd.read_pickle('corpus.pkl')
data
# Out:
#                                                   transcript        full_name
# BANKS      In December 2020, a mid-sized private life ins...     BANKS CHARGE
# BUDGET      Removal of tax exemptions under Section 80C i...     BUDGET 2020
# CAPITAL    The capital raising committee of HDFC Life Ins...  CAPITAL RAISING
# FLIPKART   Flipkart, an e-commerce firm, announced the la...   COVID LOCKDOWN
# HDFC       Private life insurer HDFC Life Insurance poste...         FLIPKART
# LOCKDOWN   The nationwide lockdown due to the coronavirus...        HDFC BANK
# MICROSOFT  Microsoft has announced that it is opening an ...       HOT STOCKS
# PLUTO      Some 94 years ago on February 18, 1930, Americ...        MICROSOFT
# POKEMON    In a creative effort to inform others about to...     PLUTO PLANET
# SOLAR      A total solar eclipse is poised to adorn the s...          POKEMON
# SPOTIFY    Popular music streaming platform Spotify has a...    SOLAR ECLIPSE
# ...

# %%
# Extract only Adam Devine Wong's text
topic1 = data.transcript.loc['BANKS']
topic1[:200]
# Out:
# 'In December 2020, a mid-sized private life insurance CEO found out that their bank partner, a South India-based private lender, was in talks with a rival firm for a possible tie-up. It was a problem b'

# %% [markdown]
# ## Build a Markov Chain Function

# %% [markdown]
# We are going to build a simple Markov chain function that creates a dictionary:
# * The keys should be all of the words in the corpus
# * The values should be a list of the words that follow the keys

# %%
from collections import defaultdict

def markov_chain(text):
    '''The input is a string of text and the output will be a dictionary with each word as
       a key and each value as the list of words that come after the key in the text.'''

    # Tokenize the text by word, though including punctuation
    words = text.split(' ')

    # Initialize a default dictionary to hold all of the words and next words
    m_dict = defaultdict(list)

    # Create a zipped list of all of the word pairs and put them in word: list of next words format
    for current_word, next_word in zip(words[0:-1], words[1:]):
        m_dict[current_word].append(next_word)

    # Convert the default dict back into a dictionary
    m_dict = dict(m_dict)
    return m_dict

# %%
# Create the dictionary for Ali's routine, take a look at it
ali_dict = markov_chain(topic1)
ali_dict
# Out:
# {'In': ['December', 'a', 'other', 'the'],
#  'December': ['2020,'],
#  '2020,': ['a'],
#  'a': ['mid-sized',
#   'South',
#   'rival',
#   'possible',
#   'problem',
#   'break-up.',
#   'bank.',
#   'chunk',
#   'decade,',
#   'private',
#   'bank',
#   'Mumbai',
#   'core',
#   'non-bank',
#   'rejig',
#   'new',
#   'possibility',
#   'concern?',
#   'concern',
#   'bid',
#   'basic',
#   'branch',
#   'lion’s',
#   'fact',
#   'major'],
#  'mid-sized': ['private'],
#  'private': ['life',
#   'lender,',
#   'life',
#   'life',
#   'life',
#   'sector',
#   'life',
#   'life',
#   'life'],
#  'life': ['insurance',
#   'insurance',
#   'insurance',
#   'insurers,',
#   'insurer’s',
#   'insurers,',
#   'insurers,',
#   'insurers,'],
#  'insurance': ['CEO',
#   'company',
#   "company's",
#   'distribution',
#   "company's",
#   'brings',
#   'consultant',
#   'regulator',
#   'companies',
#   'distribution.',
#   'products',
#   'is'],
#  'CEO': ['found', 'acted', 'is'],
# ...

# %% [markdown]
# ## Create a Text Generator

# %% [markdown]
# We're going to create a function that generates sentences. It will take two things as inputs:
# * The dictionary you just created
# * The number of words you want generated
#
# Here are some examples of generated sentences:
#
# >'Shape right turn– I also takes so that she’s got women all know that snail-trail.'
#
# >'Optimum level of early retirement, and be sure all the following Tuesday… because it’s too.'

# %%
import random

def generate_sentence(chain, count=15):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    for i in range(count-1):
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    # End it with a period
    sentence += '.'
    return(sentence)

# %%
generate_sentence(ali_dict)
# Out:
# "Fee income. Moneycontrol spoke to stay 'exclusive'. The insurance distribution channel, namely banks, as per."

# %% [markdown]
# ### Assignment:
# 1. Generate sentence for other comedians also.
# 2. Try making the generate_sentence function better. Maybe allow it to end with a random punctuation mark or end whenever it gets to a word that already ends with a punctuation mark.

# %% [markdown]
# #### Ques 1

# %%
# Assuming you have a DataFrame named 'data' containing the transcripts
# and functions markov_chain and generate_sentence are defined

comedian_list = ['BANKS','BUDGET','CAPITAL','FLIPKART','HDFC','LOCKDOWN','MICROSOFT','PLUTO','POKEMON','SOLAR','SPOTIFY','STOCKS']

for comedian in comedian_list:
    # Read in the corpus for the comedian
    comedian_text = data.transcript.loc[comedian]

    # Create the Markov chain dictionary
    comedian_dict = markov_chain(comedian_text)

    # Generate a sentence in the comedian's style
    sentence = generate_sentence(comedian_dict)

    # Print the comedian's name and the generated sentence
    print(f"{comedian.capitalize()}: {sentence}")
# Out:
# Banks: “for banks, is also impact sales of the top management of the only top five.
# Budget: "if a large set of tax regime will not be watchful of three years in.
# Capital: Percent from the money in one or more tranches, on July 23 to Rs 600.
# Flipkart: Million users. With increase in bus travel has also seen growth in the ticket price..
# Hdfc: The company had made a decline to the back of Rs 291 crore for COVID-19.
# Lockdown: April 2020 as children, pregnant women and the elderly. So rigorous tests are given as.
# Microsoft: Areas of AI London hub in London. Mustafa Suleyman, CEO, Microsoft AI hub in the.
# Pluto: Can be described as a lot of CCD cameras, scientists gradually discovered the new definition..
# Pokemon: Light for the eclipse will span 185 kilometres wide and moon cartridges from Pokémon on.
# Solar: . Total eclipses, known for totality. Solar Eclipse Timer App Developed by promoting a narrow.
# ...

# %% [markdown]
# #### ques 2

# %%
import random
import string

def generate_sentence(chain, min_words=5, max_words=20):
    '''Input a dictionary in the format of key = current word, value = list of next words
       along with the minimum and maximum number of words you would like to see in your generated sentence.'''

    # Capitalize the first word
    word1 = random.choice(list(chain.keys()))
    sentence = word1.capitalize()

    # Generate the second word from the value list. Set the new word as the first word. Repeat.
    while len(sentence.split()) < max_words:
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2
        # End the sentence if the word ends with punctuation
        if word2[-1] in string.punctuation:
            break

    # End it with a random punctuation mark if not already ended
    if sentence[-1] not in string.punctuation:
        sentence += random.choice(string.punctuation)

    # Ensure the generated sentence meets the minimum word requirement
    while len(sentence.split()) < min_words:
        word2 = random.choice(chain[word1])
        word1 = word2
        sentence += ' ' + word2

    return sentence

# Example usage
generate_sentence(ali_dict)
# Out:
# 'A lion’s share of insurance.'
